# %%
import pandas as pd

# %%
t = pd.read_csv("data/twits.csv")

# %%
t["web-scraper-order"] = [int(i.split("-")[-1]) for i in t["web-scraper-order"]]

# %%
t = t.sort_values(by="web-scraper-order", ascending=True)

# %%
year = 2019

prev = None 
d = [] 

for i in t.iterrows(): 
    con = i[1][-1]
    con = con.split(" ")
    if con[0] == "Dec": 
        if prev != "Dec": 
            year -= 1 
    
    a = "{} {}, {} {} {}".format(con[0], con[1].strip(","), year, con[-2], con[-1])
    d.append(a)
    prev = con[0]
    
t["published_date"] = d 
t
# Out:
#       web-scraper-order              web-scraper-start-url  \
# 5010                661  https://stocktwits.com/symbol/HON
# 220                 662  https://stocktwits.com/symbol/HON
# 227                 663  https://stocktwits.com/symbol/HON
# 434                 664  https://stocktwits.com/symbol/HON
# 3661                665  https://stocktwits.com/symbol/HON
# 3559                666  https://stocktwits.com/symbol/HON
# 1220                667  https://stocktwits.com/symbol/HON
# 5984                668  https://stocktwits.com/symbol/HON
# 3384                669  https://stocktwits.com/symbol/HON
# 1823                670  https://stocktwits.com/symbol/HON
# 2692                671  https://stocktwits.com/symbol/HON
# 2099                672  https://stocktwits.com/symbol/HON
# 2518                673  https://stocktwits.com/symbol/HON
# 608                 674  https://stocktwits.com/symbol/HON
# 5554                675  https://stocktwits.com/symbol/HON
# ...

# %%
for i in range(len(t)): 
    print(t.iloc[i,])
# Out:
# web-scraper-order                                                      661
# web-scraper-start-url                    https://stocktwits.com/symbol/HON
# content                  GE to Shrink Boston HQ Plan and Reimburse $87 ...
# published_date                                      Feb 15th, 2019 7:07 am
# Name: 5010, dtype: object
# web-scraper-order                                                      662
# web-scraper-start-url                    https://stocktwits.com/symbol/HON
# content                  Don't miss the breakout on $HON. Buy stop @152...
# published_date                                      Feb 15th, 2019 4:27 am
# Name: 220, dtype: object
# web-scraper-order                                                      663
# web-scraper-start-url                    https://stocktwits.com/symbol/HON
# content                  Honeywell International (HON) Receives a Hold ...
# published_date                                     Feb 14th, 2019 10:06 pm
# ...
